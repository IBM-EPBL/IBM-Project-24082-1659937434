# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
dg=pd.read_csv("/content/train_data.csv")

# %%
dg
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0             1              8                  c                   3
# 1             2              2                  c                   5
# 2             3             10                  e                   1
# 3             4             26                  b                   2
# 4             5             26                  b                   2
# ...         ...            ...                ...                 ...
# 318433   318434              6                  a                   6
# 318434   318435             24                  a                   1
# 318435   318436              7                  a                   4
# 318436   318437             11                  b                   2
# 318437   318438             19                  a                   7
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# ...

# %%
dg.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                                  3  radiotherapy
# 1                    Z                                  2  radiotherapy
# 2                    X                                  2    anesthesia
# 3                    Y                                  2  radiotherapy
# 4                    Y                                  2  radiotherapy
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# ...

# %%
dg.tail()
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 318433   318434              6                  a                   6
# 318434   318435             24                  a                   1
# 318435   318436              7                  a                   4
# 318436   318437             11                  b                   2
# 318437   318438             19                  a                   7
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 318433                    X                                  3  radiotherapy
# 318434                    X                                  2    anesthesia
# 318435                    X                                  3    gynecology
# 318436                    Y                                  3    anesthesia
# 318437                    Y                                  5    gynecology
#
#        Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# ...

# %%
dg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318438 entries, 0 to 318437
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   case_id                            318438 non-null  int64
#  1   Hospital_code                      318438 non-null  int64
#  2   Hospital_type_code                 318438 non-null  object
#  3   City_Code_Hospital                 318438 non-null  int64
#  4   Hospital_region_code               318438 non-null  object
#  5   Available Extra Rooms in Hospital  318438 non-null  int64
#  6   Department                         318438 non-null  object
#  7   Ward_Type                          318438 non-null  object
#  8   Ward_Facility_Code                 318438 non-null  object
#  9   Bed Grade                          318325 non-null  float64
#  10  patientid                          318438 non-null  int64
# ...

# %%
dg.dtypes
# Out:
# case_id                                int64
# Hospital_code                          int64
# Hospital_type_code                    object
# City_Code_Hospital                     int64
# Hospital_region_code                  object
# Available Extra Rooms in Hospital      int64
# Department                            object
# Ward_Type                             object
# Ward_Facility_Code                    object
# Bed Grade                            float64
# patientid                              int64
# City_Code_Patient                    float64
# Type of Admission                     object
# Severity of Illness                   object
# Visitors with Patient                  int64
# Age                                   object
# Admission_Deposit                    float64
# Stay                                  object
# dtype: object

# %%
dg.shape
# Out:
# (318438, 18)

# %%
dg.isnull()
# Out:
#         case_id  Hospital_code  Hospital_type_code  City_Code_Hospital  \
# 0         False          False               False               False
# 1         False          False               False               False
# 2         False          False               False               False
# 3         False          False               False               False
# 4         False          False               False               False
# ...         ...            ...                 ...                 ...
# 318433    False          False               False               False
# 318434    False          False               False               False
# 318435    False          False               False               False
# 318436    False          False               False               False
# 318437    False          False               False               False
#
#         Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# ...

# %%
dg.describe()
# Out:
#              case_id  Hospital_code  City_Code_Hospital  \
# count  318438.000000  318438.000000       318438.000000
# mean   159219.500000      18.318841            4.771717
# std     91925.276848       8.633755            3.102535
# min         1.000000       1.000000            1.000000
# 25%     79610.250000      11.000000            2.000000
# 50%    159219.500000      19.000000            5.000000
# 75%    238828.750000      26.000000            7.000000
# max    318438.000000      32.000000           13.000000
#
#        Available Extra Rooms in Hospital      Bed Grade      patientid  \
# count                      318438.000000  318325.000000  318438.000000
# mean                            3.197627       2.625807   65747.579472
# std                             1.168171       0.873146   37979.936440
# min                             0.000000       1.000000       1.000000
# 25%                             2.000000       2.000000   32847.000000
# ...

# %%
dg.cov()
# Out:
#                                         case_id  Hospital_code  \
# case_id                            8.450257e+09  -34145.255936
# Hospital_code                     -3.414526e+04      74.541723
# City_Code_Hospital                -3.237513e+03       3.436541
# Available Extra Rooms in Hospital  4.572484e+03      -0.601495
# Bed Grade                          1.099855e+03      -0.103553
# patientid                         -1.448858e+07     751.114364
# City_Code_Patient                  2.844142e+04      -0.636355
# Visitors with Patient              2.122606e+02      -0.434073
# Admission_Deposit                 -4.592730e+06     426.413524
#
#                                    City_Code_Hospital  \
# case_id                                  -3237.513037
# Hospital_code                                3.436541
# City_Code_Hospital                           9.625726
# Available Extra Rooms in Hospital           -0.165887
# Bed Grade                                   -0.133597
# ...

# %%
sns.heatmap (dg.corr(),annot=False)

plt.title("correlation Matrix")

plt.show()

# %%
dg["Admission_Deposit"].hist(bins=10)

plt.title("Histogram for Admission_Deposit ")

plt.show()

# %%
dg["patientid"].hist(bins=100)

plt.title("Histogram for patientid ")

plt.show()
